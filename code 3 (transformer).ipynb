# %%
from transformers import VisionEncoderDecoderModel, ViTImageProcessor, AutoTokenizer
import torch
from PIL import Image

#Without fine tunned
model = VisionEncoderDecoderModel.from_pretrained("nlpconnect/vit-gpt2-image-captioning")

#With fine tunned
#model = VisionEncoderDecoderModel.from_pretrained("./image-captioning-output/checkpoint-160")

feature_extractor = ViTImageProcessor.from_pretrained("nlpconnect/vit-gpt2-image-captioning")
tokenizer = AutoTokenizer.from_pretrained("nlpconnect/vit-gpt2-image-captioning")

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model.to(device)
# Out:
# 2023-06-19 00:05:36.273851: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Some weights of the model checkpoint at nlpconnect/vit-gpt2-image-captioning were not used when initializing VisionEncoderDecoderModel: ['decoder.transformer.h.9.crossattention.masked_bias', 'decoder.transformer.h.9.crossattention.bias', 'decoder.transformer.h.7.crossattention.masked_bias', 'decoder.transformer.h.6.attn.bias', 'decoder.transformer.h.1.crossattention.bias', 'decoder.transformer.h.7.crossattention.bias', 'decoder.transformer.h.10.attn.bias', 'decoder.transformer.h.2.crossattention.bias', 'decoder.transformer.h.8.attn.bias', 'decoder.transformer.h.6.crossattention.masked_bias', 'decoder.transformer.h.0.crossattention.bias', 'decoder.transformer.h.5.crossattention.masked_bias', 'decoder.transformer.h.7.attn.bias', 'decoder.transformer.h.2.attn.masked_bias', 'decoder.transformer.h.11.crossattention.bias', 'decoder.transformer.h.8.crossattention.bias', 'decoder.transformer.h.1.attn.masked_bias', 'decoder.transformer.h.4.attn.masked_bias', 'decoder.transformer.h.3.attn.masked_bias', 'decoder.transformer.h.11.attn.masked_bias', 'decoder.transformer.h.3.attn.bias', 'decoder.transformer.h.8.crossattention.masked_bias', 'decoder.transformer.h.0.attn.bias', 'decoder.transformer.h.9.attn.masked_bias', 'decoder.transformer.h.1.attn.bias', 'decoder.transformer.h.0.crossattention.masked_bias', 'decoder.transformer.h.7.attn.masked_bias', 'decoder.transformer.h.0.attn.masked_bias', 'decoder.transformer.h.9.attn.bias', 'decoder.transformer.h.8.attn.masked_bias', 'decoder.transformer.h.5.crossattention.bias', 'decoder.transformer.h.10.crossattention.masked_bias', 'decoder.transformer.h.2.crossattention.masked_bias', 'decoder.transformer.h.11.crossattention.masked_bias', 'decoder.transformer.h.2.attn.bias', 'decoder.transformer.h.6.crossattention.bias', 'decoder.transformer.h.3.crossattention.masked_bias', 'decoder.transformer.h.5.attn.masked_bias', 'decoder.transformer.h.4.crossattention.bias', 'decoder.transformer.h.11.attn.bias', 'decoder.transformer.h.10.attn.masked_bias', 'decoder.transformer.h.6.attn.masked_bias', 'decoder.transformer.h.3.crossattention.bias', 'decoder.transformer.h.5.attn.bias', 'decoder.transformer.h.4.crossattention.masked_bias', 'decoder.transformer.h.10.crossattention.bias', 'decoder.transformer.h.1.crossattention.masked_bias', 'decoder.transformer.h.4.attn.bias']
# - This IS expected if you are initializing VisionEncoderDecoderModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing VisionEncoderDecoderModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# VisionEncoderDecoderModel(
#   (encoder): ViTModel(
#     (embeddings): ViTEmbeddings(
#       (patch_embeddings): ViTPatchEmbeddings(
#         (projection): Conv2d(3, 768, kernel_size=(16, 16), stride=(16, 16))
#       )
#       (dropout): Dropout(p=0.0, inplace=False)
#     )
#     (encoder): ViTEncoder(
#       (layer): ModuleList(
#         (0-11): 12 x ViTLayer(
#           (attention): ViTAttention(
#             (attention): ViTSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.0, inplace=False)
#             )
#             (output): ViTSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.0, inplace=False)
#             )
#           )
#           (intermediate): ViTIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): ViTOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (dropout): Dropout(p=0.0, inplace=False)
#           )
#           (layernorm_before): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#           (layernorm_after): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#         )
#       )
#     )
#     (layernorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#     (pooler): ViTPooler(
#       (dense): Linear(in_features=768, out_features=768, bias=True)
#       (activation): Tanh()
#     )
#   )
#   (decoder): GPT2LMHeadModel(
#     (transformer): GPT2Model(
#       (wte): Embedding(50257, 768)
#       (wpe): Embedding(1024, 768)
#       (drop): Dropout(p=0.1, inplace=False)
#       (h): ModuleList(
#         (0-11): 12 x GPT2Block(
#           (ln_1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (attn): GPT2Attention(
#             (c_attn): Conv1D()
#             (c_proj): Conv1D()
#             (attn_dropout): Dropout(p=0.1, inplace=False)
#             (resid_dropout): Dropout(p=0.1, inplace=False)
#           )
#           (ln_2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (crossattention): GPT2Attention(
#             (c_attn): Conv1D()
#             (q_attn): Conv1D()
#             (c_proj): Conv1D()
#             (attn_dropout): Dropout(p=0.1, inplace=False)
#             (resid_dropout): Dropout(p=0.1, inplace=False)
#           )
#           (ln_cross_attn): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (mlp): GPT2MLP(
#             (c_fc): Conv1D()
#             (c_proj): Conv1D()
#             (act): NewGELUActivation()
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (ln_f): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#     )
#     (lm_head): Linear(in_features=768, out_features=50257, bias=False)
#   )
# )

# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"]="0,1,2"

# %%
def predict_step(image_paths,max_length,num_beams):
    gen_kwargs = {"max_length": max_length, "num_beams": num_beams}
    images = []
    for image_path in image_paths:
        i_image = Image.open(image_path)
        if i_image.mode != "RGB":
            i_image = i_image.convert(mode="RGB")

        images.append(i_image)

    pixel_values = feature_extractor(images=images, return_tensors="pt").pixel_values
    pixel_values = pixel_values.to(device)

    output_ids = model.generate(pixel_values, **gen_kwargs)

    preds = tokenizer.batch_decode(output_ids, skip_special_tokens=True)
    preds = [pred.strip() for pred in preds]
    return preds

# %%
print(" --------------- Zero Shot Evaluation --------------- ")
print("Greedy: ",(predict_step(['../dataset/my_dataset/train/0395.jpg'],24,1)[0]))
print("Beam (N=3): ",(predict_step(['../dataset/my_dataset/train/0395.jpg'],24,3)[0]))
print("Beam (N=5): ",(predict_step(['../dataset/my_dataset/train/0395.jpg'],24,5)[0]))
# Out:
#  --------------- Zero Shot Evaluation ---------------
# Greedy:  a large clock tower towering over a city
# Beam (N=3):  a tall clock tower towering over a city
# Beam (N=5):  a tall clock tower towering over a city

# %%
token_path = "../dataset/my_dataset/captions2.txt"
images_path = '../dataset/my_dataset/train/'

# %%
doc = open(token_path,'r').read()
print(doc[:410])
# Out:
# 0001.jpg#0 an aerial view of a town with lots of buildings and trees
# 0001.jpg#1 a town with lots of tall buildings and trees
# 0001.jpg#2 an aerial view of a town with tall buildings
# 0001.jpg#3 a group of under construction buildings in a town with lots of trees around
# 0002.jpg#0 an aerial view of a town with lots of buildings and trees
# 0002.jpg#1 a town with many buildings and trees
# 0002.jpg#2 a lot of build

# %%
descriptions = dict()
all_image_id = []
for line in doc.split('\n'):
    tokens = line.split()
    if len(line) > 2:
        image_id = tokens[0].split('.')[0]
        image_desc = ' '.join(tokens[1:])
        if image_id not in all_image_id:
            all_image_id.append(image_id)
        if image_id not in descriptions:
            descriptions[image_id] = list()
        descriptions[image_id].append(image_desc)

# %%
print("Total images:",len(all_image_id))
# Out:
# Total images: 1256

# %%
import string
table = str.maketrans('', '', string.punctuation)
for key, desc_list in descriptions.items():
    for i in range(len(desc_list)):
        desc = desc_list[i]
        desc = desc.split()
        desc = [word.lower() for word in desc]
        desc = [w.translate(table) for w in desc]
        desc_list[i] =  ' '.join(desc)

# %%
vocabulary = set()
for key in descriptions.keys():
        [vocabulary.update(d.split()) for d in descriptions[key]]

print('Original Vocabulary Size: %d' % len(vocabulary))
# Out:
# Original Vocabulary Size: 878

# %%
lines = list()
for key, desc_list in descriptions.items():
    for desc in desc_list:
        lines.append(key + ' ' + desc)
new_descriptions = '\n'.join(lines)

# %%
from sklearn.model_selection import train_test_split
train, test = train_test_split(all_image_id,test_size=0.2035)
#train, val = train_test_split(train,test_size=0.177)
print(len(train))
print(len(test))
#print(len(val))
# Out:
# 1000
# 256

# %%
train_img = []
for i in train:
    path = images_path + i + '.jpg'
    train_img.append(path)

test_img = []
for i in test:
    path = images_path + i + '.jpg'
    test_img.append(path)

# %%
train_descriptions = dict()
for line in new_descriptions.split('\n'):
    tokens = line.split()
    image_id, image_desc = tokens[0], tokens[1:]
    if image_id in train:
        if image_id not in train_descriptions:
            train_descriptions[image_id] = list()
        desc = 'startseq ' + ' '.join(image_desc) + ' endseq'
        train_descriptions[image_id].append(desc)

print('Descriptions: train = %d' % len(train_descriptions))
# Out:
# Descriptions: train = 1000

# %%
test_descriptions = dict()
for line in new_descriptions.split('\n'):
    tokens = line.split()
    image_id, image_desc = tokens[0], tokens[1:]
    if image_id in test:
        if image_id not in test_descriptions:
            test_descriptions[image_id] = list()
        desc = ' '.join(image_desc)
        test_descriptions[image_id].append(desc)
    

print('Descriptions: test = %d' % len(test_descriptions))
# Out:
# Descriptions: test = 256

# %%
print(train_img[0])
print(test_img[0])
# Out:
# ../dataset/my_dataset/train/0644.jpg
# ../dataset/my_dataset/train/0106.jpg

# %%
file_name = "test_img.txt"  # Change this to your desired file name
file_path = "./exp6/" + file_name  # Change the path if necessary

# Open the file in write mode
with open(file_path, 'w') as file:
    # Iterate over each element in the array
    for element in test_img:
        # Write the element to a new line in the file
        file.write(' '.join(element) + '\n')

# Print a message indicating the file creation
print(f"The file '{file_name}' has been created and populated with the array elements.")
# Out:
# The file 'test_img.txt' has been created and populated with the array elements.

# %%
test_descriptions
# Out:
# {'0002': ['an aerial view of a town with lots of buildings and trees',
#   'a town with many buildings and trees',
#   'a lot of buildings in a town surrounded by green trees',
#   'an aerial view of a town with many buildings and trees'],
#  '0003': ['an aerial view of a town with lots of buildings and trees',
#   'a town with lots of tall buildings around',
#   'an aerial view of a city with many buildings',
#   'a lot of buildings in a town with green trees in background'],
#  '0006': ['an aerial view of a town with lots of buildings and trees',
#   'many buildings and road surrounded by trees in a town',
#   'a rotaty in the middle of town with many buildings and trees around it',
#   'a view of a large area with many buildings and trees'],
#  '0022': ['an aerial view of urban area with road and buildings',
#   'an urban area with road and buildings',
#   'an aerial view of urban area with construction site near long road and building',
#   'an aerial view of buildings with road and construction sites'],
#  '0029': ['an aerial view of an industrial area with buildings on green field',
#   'an aerial view of a large building with a lot of green grass around',
#   'a tall building near blue roof sheds on green field',
#   'an aerial view of tall building near blue roof sheds on green field'],
#  '0051': ['many buildings with green lawn in the middle and construction sites in the background',
#   'an aerial view of a construction site with buildings in front of it',
#   'a green lawn and under construction site near two large buildings',
#   'an aerial view of a green lawn and under construction site near two large buildings'],
#  '0054': ['a top view of lush green field with tall buildings and road around',
#   'an aerial view of lush green field with tall buildings and road around',
#   'an aerial view of urban area with tall building and road in the middle of green bushes',
#   'many tall white buildings and a circular intersection near large green area with lot of trees'],
#  '0056': ['an aerial view of urban area with tall buildings and road',
#   'an aerial view of tall buildings surrounded by road',
#   'many curved building in red and white stripes surrounded by road and green bushes',
#   'an aerial view of curved buildings in the middle of town'],
#  '0064': ['an aerial view of a construction site with a crane in the background',
#   'an aerial view of large field with construction sites and tall white buildings',
#   'a construction site with cranes near many tall white buildings',
#   'an aerial view of an large empty field with tall white buildings'],
#  '0069': ['an aerial view of a town with a lot of buildings',
#   'an aerial view of urban area with lot of buildings with many trees around',
#   'a lot of buildings and trees near a roundabout',
#   'an aerial view of town with lot of tall buildings and circular intersection'],
#  '0070': ['an aerial view of a large building complex in the middle of a green field',
#   'an aerial view of a group of building with a lot of green trees around',
#   'many under construction buildings surrounded by lush green field',
#   'an aerial view of large green field with many buildings in the middle and a water body in the background'],
#  '0082': ['a green lawn surrounded by tall buildings',
#   'an aerial view of a green lawn in front of buildings',
#   'many buildings with a green lawn in middle of it',
#   'a green lawn with lot of trees in front of tall buildings'],
#  '0087': ['a building with lot of glass windows with small green lawn in front',
#   'a building with many windows and small lawn',
#   'a tall building with a large number of windows',
#   'a building with many windows and a crane on top'],
#  '0088': ['a building with lot of glass windows',
#   'a building with many windows',
#   'a tall building with a large number of windows',
#   'a building with many windows and a crane on top'],
#  '0092': ['an aerial view of a construction site near a building',
#   'an aerial view of a building with green lawn near under construction site',
#   'an under construction site with large building and large green field in front of it',
#   'an aerial view of building and green lawn with construction site on background'],
#  '0099': ['many buildings with a green lawn in middle of it',
#   'an aerial view of a grassy area in front of a building',
#   'a green lawn surrounded by buildings',
#   'a green lawn with lot of trees in front of tall buildings'],
#  '0100': ['many buildings with a green lawn in middle of it',
#   'an aerial view of a grassy area in front of a building',
#   'a green lawn surrounded by buildings',
#   'a green lawn with lot of trees in front of tall buildings'],
#  '0103': ['a top view of buildings with green lawn and footpath',
#   'a building with a footpath path and grass',
#   'an aerial view of a building and a green lawn',
#   'a top view of a building and a green lawn'],
#  '0106': ['an aerial view of building with roof',
#   'an aerial view of a building with a large roof',
#   'a top view of building with large roof',
#   'an aerial view of the roof top of the building'],
#  '0123': ['a top view of green lawn in front of tall building',
#   'a large green field in front of a large building',
#   'a tall building with green lawn in front of it',
#   'a top view of tall building with green lawn in front of it'],
#  '0132': ['an aerial view of a large building with many windows',
#   'an aerial view of a building with a roof top',
#   'a building with green lawn in front of it',
#   'a tall building with some under construction buildings in the background'],
#  '0133': ['an aerial view of a large building with many windows',
#   'an aerial view of a building with a roof top',
#   'a building with green lawn in front of it',
#   'an aerial view of the building with lot of green bushes in the background'],
#  '0135': ['an aerial view of two buildings with green lawn in front of them',
#   'a green lawn in front of buildings',
#   'a top view of buildings and green lawn',
#   'a green grassy area surrounded by tall buildings'],
#  '0145': ['an aerial view of tall buildings and parking lot',
#   'an aerial view of a large building with a lot of parking spaces',
#   'many vehicles parked in parking lot in front of tall building',
#   'an aerial view of an urban area with many buildings and parking lot'],
#  '0147': ['an aerial view of a large building with many windows and hole on roof',
#   'an aerial view of a building with a large hole on roof',
#   'an aerial view of the roof of the building with solar panels and hole',
#   'a tall building with multiple windows and large roof'],
#  '0156': ['a tall building with a green lawn in front of it',
#   'a tall building with green grassy area',
#   'a tall building with glass facade has green lawn in front of it',
#   'a green lawn in front of tall glass facade building'],
#  '0157': ['a large grassy area surrounded by tall buildings and consutuction sites',
#   'a tall building with many windows near to green lawn',
#   'an aerial view of graasy area with tall buildings',
#   'a large building with a green lawn and a under construction site'],
#  '0158': ['many tall buildings with green lawn in front of it',
#   'an areial view of tall buildings with grassy area',
#   'a view of buildings with green lawn and trees near by',
#   'a large green lawn and trees in front of tall buildings'],
#  '0174': ['many vehicle parked near the tall building',
#   'an aerial view of a parking lot near a tall building',
#   'many vehicles parked on the sidewalk outside of a building',
#   'a building with a lot of vehicles parked in front of it'],
#  '0183': ['a view of a building with a crane on top',
#   'a view of roof top of the building with crane on top',
#   'a roof of the industrial building with crane in the background',
#   'a top floor of the building with many windows'],
#  '0184': ['a large building with stairs in front of it',
#   'a large glass facade building with a yellow railing',
#   'a building with a large glass facade and stairs',
#   'a building with many windows has glass facade and stairs'],
#  '0186': ['a green box in the middle of a large building',
#   'a glass facade tall building with many windows and stairs and railings',
#   'a glass facade building has lot of windows on it',
#   'a large building has yellow railing and green box in middle of it'],
#  '0190': ['a building with lot of windows on it',
#   'a large building with modern design',
#   'a tall building has many windows on it',
#   'a tall building with modern architecture'],
#  '0192': ['a lot of people stand on ground floor of the building',
#   'a large building with a banner and lot of people near it',
#   'a group of people standing outside the building',
#   'a group of people walking on red and green carpet in front of building'],
#  '0193': ['a large building with stairs in front of it',
#   'a large glass facade building with a yellow railing',
#   'a building with a large glass facade and stairs',
#   'a building with lot of windows has glass facade and stairs'],
#  '0197': ['a top view of building with solar panels on roof',
#   'an aerial view of a roof top of the building',
#   'a building with lot of solar panels and large hole on the roof',
#   'an aerial view of a building with a hole in the middle of roof'],
#  '0201': ['an aerial view of many large building with green lawn in middle of them',
#   'a large buildings with a green lawn in front of it',
#   'a green grassy area with lot of trees in middle of tall buildings',
#   'an aerial view of urban area with tall buildings and green lawn'],
#  '0205': ['an aerial view of morden buildings with green lawn in front of it',
#   'a large grassy area surrounded by tall buildings',
#   'an aerial view of three tall buildings with green lawn',
#   'an areial view of urban area with tall building in middle of under construction site'],
#  '0209': ['many trees in front of large buildings',
#   'a large building with many trees in front of it',
#   'many trees on large grassy area in front of tall building',
#   'an aerial view of a large building with trees and green lawn in front of it'],
#  '0211': ['a rotary with buildings and trees in the background',
#   'a large rotary has many plants in middle of it with buildings in background',
#   'a rotary with vehicles in front of red and white buildings',
#   'a lot of vehicles and people near the rotary'],
#  '0213': ['an aerial view of circular intersection with many vehicles and building',
#   'a lot of vehicles on road near the red and white building',
#   'a large rotary with many vehicles near the buildings',
#   'a red and white buildings next to green bushes and rotary'],
#  '0220': ['an aerial view of a roundabout with a circular design in the middle',
#   'an aerial view of an circular intersection in a rural area',
#   'a large rotary with lot of plants in the middle of green bushes',
#   'a road with large circular intersection in rural area'],
#  '0225': ['a top view of roundabout with two buses',
#   'two buses are parked on rotary',
#   'a top view of circular intersection with two buses parked near by',
#   'an aerial view of a roundabout with plants and buses'],
#  '0226': ['a circular intersection next to under construction site',
#   'an under construction site next to empty road and roundabout',
#   'an aerial view of circular rotary near construction site',
#   'a top view of roundabout next to construction site'],
#  '0227': ['a circular intersection with a bus stop and lot of plants',
#   'an aerial view of rotary has lot of plants in middle of it',
#   'a bus standing near the circular intersection',
#   'an aerial view of roundabout with many vehicles around'],
#  '0228': ['an aerial view of rotary with red and white buildings in background',
#   'a circular intersection near by green bushes and building',
#   'an aerial view of red and white building next to rotary and green bushes',
#   'an aerial view of a bus stand and a building'],
#  '0231': ['a large roundabout with lot of people and vehicles',
#   'an aerial view of a circular garden area with vehicles parked near by',
#   'a red bus driving down the street next to a circular green park',
#   'a green circular park with many vehicles and people around it'],
#  '0232': ['a top view of roundabout with bus stand and vehicles',
#   'an aerial view of a roundabout with a car and a bus',
#   'an aerial view of a roundabout with many vehicles',
#   'a bus is parked near bus stop on roundabout'],
#  '0233': ['an aerial view of a roundabout with two buses on it',
#   'an aerial view of a roundabout in a rural area',
#   'a road with circular intersection has buses on it',
#   'an aerial view of circular intersection in middle of green bushes'],
#  '0239': ['an top view of farm land with road and buildings',
#   'a road and bildings near the large green field',
#   'an aerial view of large green field with road and buildings',
#   'a green farm land with many trees around'],
#  '0244': ['an aerial view of a rural area with mobile towers',
#   'an aerial view of a farm land with a building and two mobile towers',
#   'an aerial view of a large field with a building and a lot of trees',
#   'an aerial view of farm land with lot of trees and building'],
#  '0245': ['a farm land with lot of trees',
#   'an aerial view of a fram land with lot of trees',
#   'an aerial view of green farm land',
#   'a green farm land with many trees around'],
#  '0249': ['many blue buildings next to green farms',
#   'a lush green field next to blue buildings',
#   'a group of building and vehicles near green field',
#   'an aerial view of lush green field next to blue buildings'],
#  '0250': ['a farm land with lot of trees and road',
#   'an aerial view of a fram land with lot of trees',
#   'an aerial view of green farm land and road',
#   'a green farm land with many trees around'],
#  '0254': ['a farm land with lot of trees and road',
#   'an aerial view of a fram land with lot of trees',
#   'an aerial view of green farm land and road',
#   'a green farm land with many trees around'],
#  '0264': ['an aerial view of a dirt road and a dirt field',
#   'an aerial view of a dirt road in a rural area',
#   'an aerial view of rural area with dirt field',
#   'a dirt road is surrounded by trees and dirt field'],
#  '0267': ['an aerial view of construction site in the middle of green field',
#   'a lot of trees around under construction building',
#   'an under construction building surrounded by large green field',
#   'an aerial view of under construction building surrounded by large green field'],
#  '0273': ['an aerial view of a dirt road and trees',
#   'an aerial view of dirt road near green bushes',
#   'an aerial view of dirt road and green bushes',
#   'an aerial view of a grassy area with bushes and dirt road'],
#  '0279': ['a under constuction building with a crane on the top of it',
#   'a large building with a green lawn and a under construction site',
#   'an areial view of urban area with tall buildings and construction site',
#   'a new building is being constructed behind tall building and green lawn'],
#  '0283': ['a green lawn surrounded by tall buildings',
#   'a green lawn in front of buildings',
#   'many buildings with a green lawn in middle of it',
#   'a green lawn with lot of trees in front of tall buildings'],
#  '0285': ['an aerial view of trees with buildings in background',
#   'a group of green trees in front of buildings',
#   'an aerial view of trees in front of buildings',
#   'many trees and grass in a park with a building in the background'],
#  '0293': ['a large green lawn in middle of tall buildings',
#   'an aerial view of large green lawn with lot of trees in middle of tall buildings',
#   'an aerial view of an empty park with a lot of trees',
#   'a green lawn with lot of trees surrounded by buildings'],
#  '0295': ['a large green lawn with lot of trees and people',
#   'an aerial view of large green lawn with lot of trees',
#   'an aerial view of park with lot of trees and building',
#   'many people walking on large grassy area with lot of trees'],
#  '0299': ['an aerial view of a grassy field surrounded by buildings',
#   'an aerial view of a large green lawn in the middle of buildings',
#   'a large green grassy area in front of tall buildings',
#   'a green lawn in front of buildings'],
#  '0301': ['an top view of a grassy field surrounded by buildings',
#   'an aerial view of a large green lawn in the middle of buildings',
#   'a large green grassy area in front of tall buildings',
#   'a green lawn in front of buildings'],
#  '0303': ['a green lawn with walkway and street lamp',
#   'a street lamp and big stone on green park',
#   'a street lamp on green lawn near walkway',
#   'an aerial view of green lawn with walkway and street lamp'],
#  '0307': ['many people walking along a road near the trees',
#   'many trees in the middle of road with lot of people',
#   'an aerial view of road with lot of people near the trees',
#   'aerial view of a street with a small house on the side of the road'],
#  '0316': ['a footpath has many sitting stones and trees',
#   'a path with few trees and many sitting stones',
#   'many sitting stones on foorpath near small trees',
#   'a sidewalk with a sitting stones and green trees on the side of the road'],
#  '0318': ['many red and yellow flower plants with sign board',
#   'a lot of yellow and red flower plants',
#   'many yellow and red flower plants',
#   'many flower plants and bushes with sign board'],
#  '0325': ['a green field with trees and roads',
#   'an aerial view of green field with trees and roads',
#   'a lush green field with many trees and roads',
#   'an aerial view of farm land with many trees and road'],
#  '0326': ['an aerial view of a entrance area with lot plants and monument in background',
#   'a dirt field with lot of plants and building in the background',
#   'an entrance in rural area with lot of plants and buildings',
#   'an entrance with lot plants on dirt area near the monument'],
#  '0339': ['an aerial view of cricket ground',
#   'a circket field with few players',
#   'an aerial view of circket ground with players',
#   'a top view of cricket ground'],
#  '0346': ['an aerial view of a tennis court and a building',
#   'an aerial view of a tennis court with a building in the background',
#   'a tennis court with white lines on the ground and a blue fence around it',
#   'a tennis court with a large metal structure in the background'],
#  '0355': ['an aerial view of cricket ground',
#   'a circket field with few players',
#   'an aerial view of circket ground with players',
#   'a group of people playing cricket on ground'],
#  '0359': ['a sports ground with basketball and volleyball court',
#   'a basketball and volleyball court in sport complex next to practice nets',
#   'an aerial view of basketball and volleyball court on sports field',
#   'an aerial view of basketball field next to volleyball court'],
#  '0371': ['a road running beside a garden with white monument on it',
#   'a purple building on the side of a road',
#   'many water fountains around a huge white triangular pillar',
#   'many rocks surrounding a tall white monument'],
#  '0376': ['aerial view of many people walking besides a garden',
#   'a garden with many benches on it',
#   'an indian map carved on a white tower',
#   'a map of india carved on a huge white pillar with iit hyderabad engraved on it'],
#  '0379': ['a huge white monument with map of india on it',
#   'a tall white monument with iit initials written on it',
#   'a gray indian map engraved on a white monument',
#   'a triangular structure with a huge grassy land behinnd it'],
#  '0387': ['a white colored monument with iit hyderabad written on it',
#   'iit hyderabad carved on a white monument with a orange logo',
#   'a red and yellow logo beside iit hyderabad text on a white structure',
#   'many buses on a road behind a white structure'],
#  '0394': ['many white multi storey buildings with a tall white monument infront of them',
#   'a tall white monument with roads passing on its side',
#   'many white multi storey buildings with trees around it',
#   'a huge white tower with a gray world map drawn on it'],
#  '0395': ['a white triangular monument with many white tall buildings behind it',
#   'a white monument in the middle of a road',
#   'a white trirangular tower on the middle of a road',
#   'a green grassy land surrounding a white tall pillar'],
#  '0402': ['top aerial view of a garden with a triangular structure on it',
#   'aerial view of a road with a garden in between',
#   'top view of many rocks and benches inside a lawn',
#   'a pathway with a triangular structure in between'],
#  '0408': ['a white monument with many tall buildings behind it',
#   'many tall residential buildings surrounded by green bushy area',
#   'an aerial view of a town with a tall pillar on garden and white building in the background',
#   'an aerial view of town with tall buildings and roads with few vehicles'],
#  '0416': ['an infinity symbol drawn on a white monument',
#   'a white monument with an infinity sign below iit initails',
#   'a tall white monument on lush green park',
#   'an aerial view of tall triangular pillar on green lawn surrounded by empty road'],
#  '0419': ['an aerial view of a parking lot with many vehicles',
#   'a parking lot with cars and motorcycles',
#   'many vehicles parked on parking lot',
#   'an aerial view of parking lot with cars and motorcycles'],
#  '0422': ['a parking lot with many cars and a tree in the middle',
#   'a parking lot with cars parked in it',
#   'an aerial view of a parking lot with many cars',
#   'a parking lot filled with lots of parked cars'],
#  '0441': ['a parking lot near building has many cars and motercycles parked in it',
#   'many cars and motercycles parked near buildings',
#   'an aerial view of parking lot next to building with lot of vehicles',
#   'a sidewalk near building with lot of vehicles parked on it'],
#  '0443': ['an aerial view of a parking lot filled with cars and motorcycles',
#   'a top view of a parking lot with many motorcycles and cars parked under the trees',
#   'a parking lot with motorcycles and cars',
#   'many motercycles and cars parked in a parking lot under the trees'],
#  '0445': ['an aerial view of a parking lot filled with cars near a building',
#   'many cars parked in a parking lot next to building and bushes',
#   'a parking lot with lot of cars near green bushes and a building',
#   'a parking lot with cars parked near the building'],
#  '0450': ['a man standing in front of a building and cars',
#   'a man standing near the cars on the side of the road',
#   'a man and two cars in front of building',
#   'a man standing on the side of street near two cars'],
#  '0461': ['a parking lot with lot of cars parked in it',
#   'a parking lot filled with many cars',
#   'many cars parked in a parking lot',
#   'a parking lot with many cars parked in it'],
#  '0468': ['a group of people standing on ground in front of white tent',
#   'a group of people gathered around a tent',
#   'a lot of people are gathered on a field in front of white tent',
#   'an aerial view of ground with many people standing near the white tent'],
#  '0469': ['a group of people standing on ground in front of white tent',
#   'a group of people gathered around a tent',
#   'a lot of people are gathered on a field in front of white tent',
#   'many people stand near the entrance of white tent'],
#  '0474': ['a group of people standing on green lawn in front of tent and red carpet',
#   'a group of people standing on lawn near a tent',
#   'a lot of people are gathered on a green field in front of white tent',
#   'many people stand near white tent'],
#  '0484': ['a couple walking down a road',
#   'a man and a woman walking on road',
#   'a man and a woman walking around trees on a street',
#   'two people walking down the road together'],
#  '0486': ['a group of people standing around a stage for event',
#   'a crowd of people standing on a dirt field',
#   'a large crowd gathered in an open field with a large balloon',
#   'a large group of people gathered around a stage for an event'],
#  '0487': ['a group of people standing in a park with a building in the background',
#   'a group of people are standing on a green field',
#   'a group of people are standing on a green field in front of building',
#   'many people gathered on green lawn in front of trees and building'],
#  '0489': ['a group of people standing in a park with a building in the background',
#   'a group of people are standing on a green field for photoshoot',
#   'a group of people are standing on a green field in front of building',
#   'many people gathered on green lawn in front of a tall building'],
#  '0492': ['a group of people standing in a park togather',
#   'a group of people are standing on a green field for photoshoot',
#   'many people are standing on a green field in a group',
#   'an aerial view of green lawn with many people posing for photoshoot'],
#  '0503': ['a group of people sitting on chairs',
#   'many people sitting on chairs to watch performance',
#   'a group of people sitting on chairs and waiting for an event',
#   'a group of people sitting on chairs and some are chatting'],
#  '0509': ['a group of people in orange gown behind a group of people in blue gown',
#   'a large group of people are sitting in rows by wearing blue and orange gowns',
#   'lot of people in blue and yellow gown in white tent',
#   'lot of people gathered in a white tent for ceremony'],
#  '0512': ['a group of people are standing on a field near multi colored flags',
#   'many people standing in a field with flags around them',
#   'lot of flags in the front of ground and metal building',
#   'lot of flags and buildings with group of people gathered in front of it'],
#  '0514': ['a large group of people sitting on chairs at a graduation ceremony',
#   'a large group of people sitting on both the sides of red carpet in a large white tent',
#   'lot of people on both the sides of red carpet',
#   'a red carpet in the middle of white tent with lot of people on both the side of carpet'],
#  '0517': ['a lot of people gathered on ground',
#   'many people standing on ground',
#   'a lot of people have gathered outside many stalls',
#   'people have gathered outside many food stalls and eating'],
#  '0519': ['a group of people standing on a green carpet',
#   'a group of people and plants on green carpet',
#   'a group of people standing next to each other in a line',
#   'a group of people standing on green carpet for ceremony'],
#  '0521': ['many people gathered in front of building',
#   'a group of people standing in front of a building',
#   'many people gathered in front of a building near a flag pole',
#   'a lot of people gathered in front of a building near a flag pole on a green carpet'],
#  '0532': ['a group of people standing on dirt field near multi colored flags',
#   'a group of people are gathered on dirt field',
#   'aerial view of people walking on a pathway with flags on a side',
#   'aerial view of people walking on a pathway with flag poles on a side'],
#  '0539': ['a busy street with lot of people and motercycles',
#   'many people and motercycle on a street',
#   'a road full of people walking and some riding bike',
#   'people walking on a road having a right diversion ahead'],
#  '0550': ['a top view of a large building complex',
#   'many tall buildings with trees between them',
#   'top view of many buildings with four blocks in each',
#   'top view of red and white buildings with trees between them'],
#  '0574': ['an aerial view of urban area with lot of buildings and road',
#   'a curved building with red and white stripes in an urban area',
#   'many curved red and white buildings with a huge farm land nearby',
#   'a red and white dom shaped cabin with many tall buildings near it'],
#  '0582': ['a tall white building near by long road',
#   'an aerial view of tall building next to road',
#   'a tall white and gray flat near with an empty road infront of it',
#   'a road divided by green grassy lanes with a tall residential building nearby'],
#  '0593': ['an aerial view of curved building near green bushes and open field',
#   'many curved buildings in red and white stripes next to open field',
#   'aerial view of a playground with nets on it near a group of red and white buildings',
#   'aerial view of many curved buildings with a playground opposite to them'],
#  '0605': ['an aerial view of tall buildings in red and white stripes with a farmlands near by',
#   'an aerial view of two tall buildings in red and white colour with green farmlands in the background',
#   'top view of buildings with narrow road and farms beside the buildings',
#   'few buildings surrounded by farmlands and having 2 towers nearby the buildings'],
#  '0611': ['an aerial view of tall white buildings',
#   'few tall buildings in white colour with a small walkway',
#   'top view of residential building surrounded by farmland',
#   'tall white residential building with 17 storey'],
#  '0618': ['a large white colour building with lot of green trees and roads in front of it',
#   'a rural area with tall white building in the background',
#   'aerial view of a building with a solar array on top of it',
#   'a view of a large apartment building with a solar pannel on roof'],
#  '0622': ['a top view of a building with white colour roof',
#   'a top view of a tall building with a solar panels on the roof',
#   'aerial view of symmetric buidling in red and white strips and road ahead of that',
#   'aerail view of buildings and under constructions building behind it'],
#  '0646': ['a road with a street light and some red and white buildings and green bushes near by',
#   'many tall buildings with a road and green trees beside it',
#   'a row of red and white buildings on the top right side of frame',
#   'a road with a street light green bushes and buildings'],
#  '0648': ['an aerial view of red and white building in a urbun area',
#   'an aerial view of urbun area with red and white buildings',
#   'arafed building with red and white stripes on the side of it',
#   'urban view of a group of buildings'],
#  '0651': ['an aerial view of white colour buildings along with open area in between them',
#   'an aerial view of tall white buildings',
#   'an aerial view of tall buildings with small gardens',
#   'an aerial view of a urban area with many tall buildings'],
#  '0663': ['an aerial view of a road with a white bus driving down it',
#   'a white bus running on a road',
#   'aerial view of a highway with a truck driving down it',
#   'a long road with a white bus on it and a green bushes on the both side'],
#  '0670': ['a car and a motorcycle are driving down a street',
#   'a busy road with flower plants on both side of road',
#   'cars and motorcycles are driving down a street',
#   'a road with a car and a motercycle on it'],
#  '0677': ['a gray car parked on the road under the trees',
#   'a street with gray car has trees and buildings around',
#   'a gray car running on the road',
#   'a road with lot of green plants on both the sides'],
#  '0684': ['a street in the middle of large buildings and car parkings lot',
#   'many cars parked on the side of road near red and white buildings',
#   'an aerial view of street with tall buildings and parking area on the side',
#   'many buildings and cars on the side of road'],
#  '0691': ['a lot of people walking on a dirt road near green bushes and empty road',
#   'a group of people walking down a dirt road',
#   'lot of people walking on dirt road near green bushes and road',
#   'an long empty road with lot og green bushes and people around'],
#  '0695': ['an aerial view of curved road on construction site',
#   'a curved road in the middle of dirt field and green bushes',
#   'a long curved road near construction site and green bushes',
#   'lot of green bushes near by curved road'],
#  '0697': ['an aerial view of four lane highway on dirt field',
#   'an aerial view of an empty road with a lot of trees',
#   'an aerial view of empty highway on brown field',
#   'a top view of empty four lane highway'],
#  '0706': ['the two road spliting into 4 roads',
#   'a divider with trees with 2 roards',
#   'a road divider with greenery',
#   'roads with divider passing through garbage dump site'],
#  '0708': ['a top view buildings',
#   'a top view of road junction',
#   'a bus driving on road going to a junction',
#   'construction site beside road'],
#  '0709': ['a road passing by under constuction bulding',
#   'the bushes near by roads',
#   'construction site beside a road junction',
#   'construction site near by dirt roads'],
#  '0723': ['a road surrouned by green bushes',
#   'a top view of car running on road',
#   'a yellow car is driving down a road with a blue fence in the background',
#   'an aerial view of a road with a car driving down it'],
#  '0730': ['two roads surrounded by bushes white towers and under constrcuture buildings',
#   'a top view of green bushes and near by roads',
#   'aerial view of a highway with a construction site in the background',
#   'a road that has a lot of construction on it'],
#  '0737': ['a top view of four passing by white tower',
#   'a top view of four roads with divider with green bushes between them',
#   'an aerial view of a road with a green area',
#   'a empty road with a green bushes and a building in the background'],
#  '0742': ['a top view of two roads splitting into five roads',
#   'a top view of five roads with divider between them having green bushes between them',
#   'an aerial view of an empty road in the middle of a city',
#   'a road with tall buildings with green bushes'],
#  '0743': ['a top view of bus running on road',
#   'a top view of roads surrounded by green bushes',
#   'aerial view of a bus driving down a road with a green field',
#   'a bus is driving down a road with a curved road'],
#  '0744': ['a top view of roads surrounded by green bushes',
#   'a top view of five roads surrounded by green bushes',
#   'aerial view of a road with a motorcycle on it',
#   'an aerial view of a road with a green grassy area'],
#  '0747': ['a man waking on footpath',
#   'a road beside footpath surrounded by green bushes',
#   'a person on a motorcycle riding down a road',
#   'a street with a person on a bike and a light post'],
#  '0748': ['a road junction with four roads',
#   'a road junction surrounded by green bushes',
#   'aerial view of a roundabout in a city',
#   'an aerial view of an intersection of road with greenery'],
#  '0751': ['a top view of four roads surrounded by green bushes',
#   'four roads are passing beside white towers',
#   'a highway with tall buildings in the background',
#   'an aerial view of an empty road in the middle of a city with green grass'],
#  '0753': ['a view of road with footpath both the side',
#   'a group of people stand on footpath',
#   'a group of people standing down a street',
#   'there are people walking down the street on the side of the road'],
#  '0755': ['two road surrouned by green bushes',
#   'two roads with divider having small trees',
#   'an aerial view of an empty road in the middle of nowhere',
#   'an aerial view of a road with a road and a fence in the background'],
#  '0758': ['a top view of roads and white buildings surrounded by green bushes',
#   'roads passing by under construction site',
#   'an aerial view of an empty road in a city',
#   'an aerial view of a road and green bushes and trees'],
#  '0763': ['a top view of roads and white buildings surrounded by green bushes',
#   'roads passing by under construction site',
#   'an aerial view of a road with a car driving down it',
#   'a road with a white vehicle on it and a building in the background'],
#  '0766': ['a top view of road surrounded by green bushes',
#   'roads with divider having small bushes',
#   'an aerial view of an empty road with trees',
#   'aerial view of a road with green bushes'],
#  '0769': ['a top view of road passing surrouned by green bushes',
#   'a top view of bus passing on road',
#   'aerial view of highway and road in the countryside',
#   'aerial view of a highway with a bus driving on it'],
#  '0770': ['a top view of bus passing on road',
#   'a top view of road passing surrouned by green bushes',
#   'an aerial view of a road and construction site',
#   'aerial view of a road with a construction site in the background'],
#  '0773': ['a top view of road passing surrouned by green bushes',
#   'a top view of roads and white buildings surrounded by green bushes',
#   'aerial view of a bus driving down a road with a green bus',
#   'an aerial view of a road with a traffic light'],
#  '0779': ['a top view of roads having divider between them',
#   'a top view of roads surrounded by green bushes',
#   'an aerial view of a curvy road in the middle of the day',
#   'an aerial view of a road with a curved road and small buildings in background'],
#  '0780': ['a top view of roads having divider between them',
#   'a top view of roads surrounded by green bushes',
#   'aerial view of a dirt road and houses',
#   'an aerial view of an empty road with trees'],
#  '0781': ['a top view of raw road surrounded by large bushes',
#   'a top view of green large bushes',
#   'aerial view of a road with trees and a road',
#   'aerial view of a road with a motorcycle and a car on it'],
#  '0794': ['a buses standing near by roads',
#   'green bushes near by roads',
#   'green bushes in centre of a road',
#   'bike driving on a road'],
#  '0798': ['a flower plants near by road',
#   'a road passing towards buildings',
#   'green bushes on road',
#   'vehicle going on the road'],
#  '0801': ['an empty road with a speed breaker',
#   'a road with small plants on it sides',
#   'a street with a lot of trees and bushes',
#   'a dirt road with trees and bushes'],
#  '0806': ['a blue colored road direction sign board placed on a footpath',
#   'an empty road with many banners on its side',
#   'a road with a sign on the side of it',
#   'an empty road with blue sign board on left'],
#  '0809': ['aerial view of a red bus infront of a bus stop',
#   'many cars parked infront of a green grassy area',
#   'a view of a parking lot with a bus and cars',
#   'there is a red bus driving down the road in a parking lot'],
#  '0811': ['many concrete slabs on the side of a road',
#   'a road with green grassy lanes on both sides',
#   'an empty road with green grassy area',
#   'a road with sitting blocks on right side'],
#  '0813': ['a road with a blue small cabin on its side',
#   'a road with a traffic light on a footpath',
#   'an empty road with blue cottage',
#   'a view of junction of 4 roads'],
#  '0817': ['a white and red building infront of a large green bushy area',
#   'aerial view of roads with many buildings nearby',
#   'an aerial view of a highway with a green field',
#   'an aerial view of a highway with a lot of grass'],
#  '0821': ['a curved road with many trees and grassy land surrounding it',
#   'a road with many light poles on it',
#   'a view of the road from the top of the hill',
#   'an aerial view of a road and a building'],
#  '0824': ['a pull up banner on a pole on the side of road',
#   'a multi storey red building on the side of a road',
#   'people walking down a sidewalk next to trees',
#   'a view of road with red buildings on left'],
#  '0829': ['many concrete curbs on a footpath next to each other',
#   'an empty road with a sidewalk',
#   'a road with a concrete curb on left',
#   'a paved road with a bike lane and a sidewalk'],
#  '0830': ['many people walking on a road with vehicles on it',
#   'a sign board placed next to many rectangular blocks',
#   'there is a motorcycle and that is driving down the road',
#   'a road with a bike lane and a tree'],
#  '0832': ['a person walking on a footpath',
#   'many blocks next to each other with a woman walking next to them',
#   'a woman walking down a sidewalk',
#   'there is a woman walking down the street on left side'],
#  '0841': ['aerial top view of many vehicles running on a busy road',
#   'top view of a highway divided with a grassy lane',
#   'aerial view of a road with cars and trees',
#   'aerial view of a road with cars and trucks driving on it'],
#  '0842': ['aerial view of a road with small sheds on it',
#   'aerial view of a farm land with road near',
#   'a birds eye view of road and buildings',
#   'an aerial view of a road with a large building in the middle'],
#  '0843': ['aerial view of many vehicles parked infront of a garden',
#   'top view of a white tall structure on an oval shaped garden',
#   'aerial view of a highway with a bus and a bus stop',
#   'an aerial view of a road with green fields'],
#  '0852': ['aerial view of a red shed with a road near by',
#   'aerial view of a red shed surrounded by trees',
#   'an aerial view of a building with a red roof',
#   'the roof of the building'],
#  '0853': ['aerial view of many vehicles on a road near a red shed',
#   'aerial top view of a red roofed shed',
#   'a red roof with a white stripe',
#   'a view of roof with cars parked on the road'],
#  '0856': ['many blue sheds in a green grassy land',
#   'aerial view of an empty street near many blue sheds',
#   'a view of many blue roofs',
#   'aerial view of blue roof sheds'],
#  '0857': ['aerial view of many blue sheds with an empty street besides it',
#   'a farm land near many blue sheds',
#   'a view of the factory buildings near green lands',
#   'an aerial view of a large building with a lot of blue roofs'],
#  '0869': ['aerial view of a man standing infront of stage',
#   'aerial view of many speakers kept on a stage',
#   'arafed stage with a green carpet and chairs in a field',
#   'a stage with a green carpet on it and a road in the background'],
#  '0872': ['aerial view of a multi storey yellow and white building near a purple tent',
#   'aerial view of a white and yellow building opposite to red and white buildings',
#   'an aerial view of an empty parking lot',
#   'an aerial view of buildings of yellow and red color'],
#  '0879': ['a green and black stage near a muddy ground',
#   'many white and brown chairs placed near a stage',
#   'an aerial view of an outdoor stage with green carpet',
#   'an aerial view of a stage with chairs near dirt area'],
#  '0884': ['a person in between rows of chairs on a red carpet',
#   'many white chairs placed in rows with red carpet path in between two rows of chair',
#   'a man standing on a red carpet in front of many white chairs',
#   'the ceremony was held in the tent with chairs and red carpet'],
#  '0890': ['a huge number of white chairs places in rows next to each other',
#   'many people inside a large white dom area with many white chairs in it',
#   'rows of white plastic chairs in an indoor event',
#   'a green carpet is on the floor with white plastic chairs'],
#  '0893': ['many people standing near many white chairs',
#   'many green plants beside chairs kept inside a tent',
#   'a large tent with chairs and people standing around',
#   'there are many people standing in a tent with chairs and a red carpet'],
#  '0895': ['a large number of chairs kept on a green carpet floor',
#   'a large number of white chairs inside a white tent',
#   'there are many white chairs in a large dome with green carpet',
#   'many white plastic chairs are in a large tent'],
#  '0897': ['aerial view of a grassy ground with white tents on it',
#   'aerial view of light poles near a white tent',
#   'an aerial view of an event with tent',
#   'two tents are set up in grassy ground'],
#  '0904': ['few small tents near a large white tent',
#   'aerial view of a ground with white tents and floodlights on it',
#   'one big and one small white tent visible on green ground',
#   'two white coloured tent can be seen from top with multi coloured flags also'],
#  '0915': ['a large white tent infront of many multi storey red and white buildings',
#   'a group of white and red colored building near a white tent',
#   'few red buildings few yellow buildings and huge white tent can be seen',
#   'from top view a big white tent with flags in front and few red and yellow coloured buildings are visilbe'],
#  '0917': ['many charis kept oustide of a big white tent',
#   'lots of luggage placed oustide a white tent',
#   'chairs black box and vehicles around a white tent can be seen',
#   'a huge white tent with some vehicles chairs and luggage outside it'],
#  '0918': ['many trucks loaded with luggage outside a big white tent',
#   'many multi color flags surrounding a big white tent',
#   'trucks and other vehicles with big black goods kept outside a white tent',
#   'a huge white tent with some vehicles chairs and luggage outside it with multi colored flag in front of it'],
#  '0922': ['aerial view of a large white tent with small white tents near it',
#   'aerial view of many people standing near white tents',
#   'top view of one big and one small white tent with people around',
#   'one small and one big white tent surrounded by many people and few vehicles'],
#  '0928': ['aerial view of large number of trees near an under construction building',
#   'aerial view of many multi storey under construction building with large number of trees aorund it',
#   'an aerial view of under construction site near by lush green trees',
#   'lot of green trees and bushes near the under construction site'],
#  '0929': ['aerial view of a oval shaped white and yellow color building',
#   'aerial view of a oval shaped building near an under construction building',
#   'an under construction site with lot of trees and and road around',
#   'an aerial view of under construction area with crane on top and green bushes around'],
#  '0938': ['an under construction building infront of a multi storey building with glass',
#   'a multi storey building with many trees infront of it',
#   'an aerial view of an under construction building with lot of trees in front of it',
#   'a tall under construction building near walkway and trees'],
#  '0943': ['aerial view of a multi storey under construction building with cranes infront of it',
#   'an under construction site with many blue iron fencing sheets',
#   'cranes in from of a huge under construction building',
#   'rods and crane surrounded by blue fence in front of a under construction building'],
#  '0949': ['aerial view of a oval shaped under construction building',
#   'a tall multi storey building surrounded by many green grassy lanes',
#   'one round building with two huge buildings around it',
#   'under construction circular building with two more buildings on its side'],
#  '0957': ['aerial view of a bulldozer moving in a dug up land infront a building',
#   'a large under construction building with a bulldozer infront of it',
#   'top view of an under construction building',
#   'under construction building with dugged up land around'],
#  '0965': ['front view of a tall multi storey under construction building with a crane on top of it',
#   'a large green grassy land with a under construction building infront of it',
#   'huge construction site and few red buildings can be seen',
#   'many under construction site along with red white stripped building at back is visible'],
#  '0974': ['many people staning on the top of a under construction building',
#   'an under construction building surrounded by many wooden rods',
#   'under construction building with few people working on it',
#   'few workers working on constructing a multistorey building'],
#  '0984': ['an aerial view of a bus moving on a road divided into two by a green lane',
#   'a bus moving on an empty road alongside a farm land',
#   'long empty road with a bus running on it and green bushes and construction site by its side',
#   'top view of a bus running on a long road with under developement area around'],
#  '0985': ['aerial view of a construction site with many blue sheds and cabins on it',
#   'aerial view of a construction site surrounded with green bushy area',
#   'top view of under construction site',
#   'an under development area with long rods all around can be seen'],
#  '0989': ['aerial view of a crane over a construction site with blue sheds on it',
#   'aerial view of blue shed with a small water body near it',
#   'top view of a construction site with a huge crane on top of it',
#   'under development site with cranes and a road on side can be seen'],
#  '0990': ['a large multi storey under construction building covered with construction nets',
#   'a dug up field infront of a under construction building',
#   'under construction multi storey building',
#   'under development building with dugged up land around'],
#  '0992': ['a grey colur multi storey under construction building',
#   'aerial view of people working on the top of a under construction building',
#   'under construction site with dugged up land around',
#   'few tall under development building surrounded by dugged up land'],
#  '0994': ['aerial view of workers standing infront of an under construction building',
# ...
#   'an under construction building with a blue cover on it',
#   'tall under construction multi storey building can be seen',
#   'under development building covered by blue nets'],
#  '1003': ['a multi storey under construction building',
#   'a multi storey under construction building with a crane on top of it',
#   'two under construction building with crane situated at the top of the building',
#   'gray colour multi storey buildings beside a road'],
#  '1009': ['an aerial view of many under construction buildings',
#   'an aerial view of people working in a construction site',
#   'under construction site with multiple roads and a crane',
#   'multiple buildings under construction and a road adjacent to it'],
#  '1012': ['an aerial view of a crane on the top of an under construction building',
#   'an aerial view of many under construction buildings',
#   'an underconstruction building having multiple floors and pillars',
#   'under construction building with a crane and blue fencing'],
#  '1014': ['an aerial view of a muddy land with green bushes',
#   'an aerial view of an under construction site',
#   'construction site with adjacent grassy wasteland',
#   'barren land with a gray elongated terrain within'],
#  '1020': ['an aerial view of a large under construction site',
#   'an under construction site near green bushy area',
#   'ariel view of a huge construction site with three cranes',
#   'construction site with large number of iron pillars crane and green bushy area'],
#  '1021': ['an aerial view of a large under construction site',
#   'an aerial view of a large ground with under construction buildings on it',
#   'large muddy ground with an ongoing construction and blue fencing',
#   'rectangular construction site on a ground'],
#  '1023': ['many people standing infront of a multi storey under construction building',
#   'an under construction building with many green trees infront of it',
#   'multistorey under construction building with construction waste lying in front',
#   'group of people standing with a gray colour under construction building in front of them'],
#  '1027': ['a road running besides a multi storey under construction building',
#   'an under construction building with a crane on the top of it',
#   'construction area with blue safety net and a crane beside green wasteland',
#   'road beside a construction site and cranes'],
#  '1029': ['an aerial view of an empty road with green lanes on its side',
#   'an empty road running next to many under construction buildings',
#   'multiple building and two roads intersecting at a point',
#   'under construction site with a green wasteland adjacent to perpendicular roads'],
#  '1032': ['an aerial view of a large under construction site',
#   'an aerial view of a construction site with a green grassy lane infront of it',
#   'huge construction site with multiple pillars and blue fencing',
#   'wasteland with a construction site and grassy lane'],
#  '1033': ['an aerial view of a road running next to an construction site',
#   'an aerial view of a construction site near green bushy area',
#   'road adjacent to a construction site and blue shades',
#   'straight road with green wasteland on left and construction site on right'],
#  '1039': ['top view of a road with a car running on it',
#   'aerial view of a road along side of a under construction site',
#   'construction site with adjacent straight road and green grassy patches',
#   'wasteland having a road and an underconstruction cuilding'],
#  '1040': ['aerial view of a road along side of a under construction site',
#   'aerial view of an under construction site with cranes on it',
#   'road with construction site on left side and green wasteland on the right side',
#   'construction site adjacent to road and buildings'],
#  '1044': ['an aerial view of an multi storey under construction building',
#   'an under construction building next to a green busy area',
#   'huge multi storey underconstruction building beside a wasteland',
#   'ariel view of a huge construction site with green wasteland beside'],
#  '1047': ['aerial view of a construction area',
#   'aerial view of a muddy land with few cabins on it',
#   'wasteland with white coloured cabins',
#   'ground with three white coloured shade area'],
#  '1048': ['aerial view of a sandy land with construction work going on',
#   'wasteland having a blue coloured shade',
#   'aerial view of a ground with green bushes on it',
#   'ariel view of a green wasteland with a blue coloured cabin'],
#  '1049': ['aerial view of a under construction building',
#   'aerial view of an under construction building next to a blue color cabin',
#   'wasteland having a blue coloured shade',
#   'aerial view of a ground with green bushes on it'],
#  '1064': ['top view of a multi storey building with gardens infront of it',
#   'top view of a construction area next to a multi storey white and gray building',
#   'gray colored tall building with a construction site on the left',
#   'construction area beside a building and green lawn'],
#  '1066': ['top view of an under construction area with a green grassy area near by',
#   'top view of a white car standing in a construction site',
#   'multi storeyed building under construction havin white colored car in front',
#   'under construction building surrounded by blue fencing'],
#  '1078': ['aerial view of a bulldozer moving on a muddy land',
#   'top view of a large under construction site',
#   'aerial view of a land with many semi circular shapes on it',
#   'aerial view of people standing on a construction site'],
#  '1082': ['top view of multi storey under construction curved building',
#   'aerial view of building in a large construction area',
#   'huge multi storey underconstruction building beside a wasteland',
#   'huge construction area with construction waste lying in front'],
#  '1084': ['top view of a curved under construction building with green bushes near it',
#   'top view of an under construction building with a muddy pathway near it',
#   'aerial view of a muddy land area with construction work going on it',
#   'aerial view of a muddy land with a multi storey building construction'],
#  '1090': ['top view of a blue shed in an under construction area',
#   'top view of a construction field with green bushes surrounding it',
#   'aerial view of a muddy land area with construction work going on it',
#   'aerial view of a muddy land with a multi storey building construction'],
#  '1091': ['top view of many sheds in an under construction area',
#   'top view of a large area with construction work going and a crane on it',
#   'aerial view of a muddy land area with construction work going on it',
#   'aerial view of a muddy land with a crane and blue fencing'],
#  '1095': ['an aerial view of a large land with lots of green trees grasses and few under construction buildings',
#   'an aerial view of under construction buildings with tall building far away',
#   'large construction site having a x shaped building a square shaped building and huge wasteland',
#   'huge construction side with multiple under construction buildings'],
#  '1099': ['aerial view of a large land area with construction work going on it',
#   'top view of an under construction multi storey building in a large field',
#   'large construction site having a x shaped building a square shaped building and huge wasteland',
#   'huge construction side with multiple under construction buildings'],
#  '1101': ['a empty road running in the middle of two under construction buildings',
#   'aerial view of a large under construction site with many green bushes around it',
#   'large construction site having a x shaped building a square shaped building and huge wasteland',
#   'huge construction side with multiple under construction buildings'],
#  '1108': ['an aerial view of a large under construction site',
#   'top view of a construction site with few green trees around it',
#   'construction site with adjacent grassy wasteland',
#   'barren land with a gray elongated terrain within'],
#  '1109': ['top view of a yellow bulldozer digging the land',
#   'top aerial view of a construction site with a yellow vehicle nearby',
#   'aerial view of a bulldozer moving on a under construction site',
#   'aerial view of a large construction site with a yellow bulldozer on it'],
#  '1116': ['an under construction building near a lush green area',
#   'many tall muti storey under construction buildings next to each other',
#   'an under construction multi storey building with blue fencing',
#   'a truck moving on a road next to under construction buildings'],
#  '1118': ['many under construction buildings infront of a lush green area',
#   'many under construction building next to each other',
#   'an under construction multi storey building with blue fencing',
#   'a truck moving on a road next to under construction buildings'],
#  '1120': ['many people working in an under constructions site',
#   'a multi storey building next to an under construction building',
#   '3 workers working on an underconstruction site',
#   'construction site beside a grey coloured multistorey building'],
#  '1129': ['a bulldozer running near an under construction building',
#   'a yellow vehicle near a multi storey under construction site',
#   'a construction site having a bulldozer in front',
#   'digging work done by a yellow vehicle'],
#  '1131': ['many multi storey buildings near many under construction buildings',
#   'an under construction site with cranes near it',
#   'multiple semicircular shaped under construction site with adjacent multistorey building',
#   'a large number of multi storey buildings with construction site on a side'],
#  '1139': ['an under construction site with large buildings infront of it',
#   'many tall buildings infront of under construction buildings',
#   'a large number of multi storey buildings with construction site on a side',
#   'multiple semicircular shaped under construction site with adjacent multistorey building'],
#  '1140': ['many under construction buildings next to each other',
#   'many multi storey under construction buildings',
#   'multiple under construction buildings and a rectangular shaped building',
#   'large construction site beside a grassy wasteland'],
#  '1153': ['a large mutli storey under construction building',
#   'an under construction building on the side of road',
#   'a tall multi storey under construction building with a pathway on its side',
#   'under construction building with a crane top of it'],
#  '1158': ['many cars standing on a busy road with people on the road',
#   'a blue car moving on a road with many cars on it',
#   'a man walking on the road with multiple people standing on the side and cars running on the road',
#   'a deep blue coloured car moving on a road with many cars on it'],
#  '1167': ['many vehicles parked near an under construction building',
#   'a man standing infront of an under construction building',
#   'many motorbikes and cycles parked on the side of construction site',
#   'few people walking around the parked vehicles'],
#  '1176': ['a crane standing on a under contruction site',
#   'a yellow vehicle standing on a ground with few people on the ground',
#   'yellow vehicle running on a wasteland with people walking around',
#   'bulldozer and few people in a wasteland having parking area on its side'],
#  '1184': ['many people staniding on a road infront of vehicles',
#   'many vehicles standing on a road with a garden on the side',
#   'a straight road consisting of vehicles and a green lawn on its left side',
#   'few vehicles moving on a road with a building on the side'],
#  '1186': ['few bikes moving on a road with green lane on the side of road',
#   'few person driving vehicles on a road with green lane its side',
#   'two motorbikes on a straight road',
#   'a road having few vehicles on it and a green lawn patch on its left'],
#  '1191': ['a car running on a road besided a green lane',
#   'a car moving on a road besides an under construction site',
#   'a green car moving on a straight road with green lawn on both sides',
#   'a straight road beside blue fencing on which a car is standing'],
#  '1196': ['a bus moving on road with green bushes on the sides of road',
#   'a road surrounded with green lanes with a bus moving on the road',
#   'a curved road with a bus and green wasteland on both sides',
#   'wasteland consisting of a road with a bus running over it'],
#  '1197': ['a car moving on a road with surrounded with green bushes',
#   'few vehicles moving on a road surrounded by green lawns',
#   'a white car moving on a road and green lawn on the left',
#   'a white car moving on a road with green lawns around the road'],
#  '1203': ['a black car moving on a road surrounded by plants',
#   'a road surrounded with beautiful green plants',
#   'a grey car moving on a road and green lawn on the right',
#   'a straight road beside green wasteland on which a car is standing'],
#  '1205': ['a person driving a vehicle on a road surrounded by many green plants',
#   'a person driving a vehicle on a road with a large building on the side of road',
#   'a bike moving on a road and green lawn on the right',
#   'a straight road beside green wasteland and multistorey building on which a bike is riding'],
#  '1207': ['many cars parked in a parking lot along side of a large building',
#   'many vehicles parked on a road infront of a green lawn',
#   'many vehicles parked in a parking lot along side of a large green wasteland',
#   'large number of vehicles parked beside a multistorey white and red coloured buildings'],
#  '1208': ['a white bus standing on a road besided a tree',
#   'a woman standing besides a vehicle on a road',
#   'a white vehicle and an auto standing near it',
#   'an auto standing near a person and a white vehicle behind it'],
#  '1212': ['a truck standing on a road with a bike infront of it',
#   'a bike parked on a road with a truck standing infront of it',
#   'a truck standing beside a road and a bike parked in front of it',
#   'a green wasteland having a road and a vehicle parked on the side'],
#  '1214': ['an under construction building with a green lawn infront of it',
#   'a vehicle moving on a road with a under construction building on the side of road',
#   'a straight road beside a construction site and few vehicles on the road',
#   'a green wasteland with a road and and few vehicles on it'],
#  '1216': ['a red bus on a road with a buiding on the side of it',
#   'a red bus moving on a road with a white bus infront of it',
#   'a bus and multiple cars beside a green lane and a road',
#   'a white vehicle and an auto standing near a bus'],
#  '1229': ['many cars running on a road with a street light on the road',
#   'a blue car moving on a road beside a tree',
#   'road with few vehicles on the road and people walking on the side',
#   'black and white cars and a man standing in front of the car'],
#  '1235': ['a white car on a road with a sign board on road',
#   'a white car running on a road besided a pathway filled with plants',
#   'a white car running on the road with many signboards',
#   'a straight road with an auto and a bike and people walking on the side'],
#  '1236': ['a white car running on a busy road with many people walking on road',
#   'a group of people walking on a road besides a footpath',
#   'a straight road with an auto and a bike and people walking on the side',
#   'a white car running on the road with many signboards'],
#  '1239': ['a group of people standing infront of car parking area',
#   'many cars parked in a ground infront of a group of people',
#   'an aerial view of a large ground area with a lot of vehicles parked in',
#   'a wasteland with several cars parked on it'],
#  '1246': ['a car and a motercyler on a street near parking lot',
#   'a parking lot with lot of cars and motercycles parked in it',
#   'an aerial view of street with car and motercycle next to parking space',
#   'an aerial view of parking filled with lot of cars and motercycles'],
#  '1252': ['a parking lot with lot of cars parked in it',
#   'many cars parked in a parking lot under the tree',
#   'a parking lot with many cars and big tree in the middle',
#   'a parking area has few cars and a tree in it']}

# %%
#beam 5
result5 = predict_step(test_img,24,5)

# %%
actual = []
predicted5 = []

for i, name in enumerate(test_img):
    predicted5.append(result5[i].split(' '))
    s = name.split('/')[-1]
    num = s.split('.')[0]
    test_cap = test_descriptions[num]
    actual_captions = [caption.split() for caption in test_cap]
    actual.append(actual_captions)
    
    
print(len(predicted5))
print(len(actual))
# Out:
# 256
# 256

# %%
from nltk.translate.bleu_score import corpus_bleu
from rouge import Rouge
from nltk.translate import meteor_score

# %%
print("Beam 5 score:")
print("BLEU-1: %f" % corpus_bleu(actual, predicted5, weights=(1.0, 0, 0, 0)))
print("BLEU-2: %f" % corpus_bleu(actual, predicted5, weights=(0.5, 0.5, 0, 0)))
print("BLEU-3: %f" % corpus_bleu(actual, predicted5, weights=(0.33, 0.33, 0.33, 0)))
print("BLEU-4: %f" % corpus_bleu(actual, predicted5, weights=(0.25, 0.25, 0.25, 0.25)))
# Out:
# Beam 5 score:
# BLEU-1: 0.707657
# BLEU-2: 0.589750
# BLEU-3: 0.492671
# BLEU-4: 0.403828

# %%
all_r1 = []
all_r2 = []
all_rl = []
all_m = []
#s = 0
for i in range(len(actual)):
    #print(s)
    #s+=1
    
    actual_captions = actual[i]
    generated_tokens = predicted5[i]
    #print("predicted: ",generated_tokens)
    rouge = Rouge()
    
    rouge_scores = []
    m_score = []
    reference_tokens = []
    
    for actual_caption in actual_captions:
        reference_tokens = actual_caption
        #print("ref tokens: ",reference_tokens)
        scores = rouge.get_scores(' '.join(generated_tokens), ' '.join(actual_caption))
        rouge_scores.append(scores[0])
        
        meteor_score_value = meteor_score.meteor_score([reference_tokens], generated_tokens)
        m_score.append(meteor_score_value)
    
    #print("rouge:", rouge_scores)
    #print("m:", m_score)
    
    m = sum(m_score)/len(m_score)
    m_score = []
    all_m.append(m)
    
    r1 = []
    r2 = []
    rl = []
    for i, actual_caption in enumerate(actual_captions):
        #print(f"Actual Caption {i+1}: {actual_caption}")
        #print("ROUGE scores:", rouge_scores[i])
        r1.append(rouge_scores[i]['rouge-1']['f'])
        r2.append(rouge_scores[i]['rouge-2']['f'])
        rl.append(rouge_scores[i]['rouge-l']['f'])
        
    all_r1.append(sum(r1)/4)
    all_r2.append(sum(r2)/4)
    all_rl.append(sum(rl)/4)

print("On greedy:")
print("r1: ",sum(all_r1)/len(all_r1))
print("r2: ",sum(all_r2)/len(all_r2))
print("rl: ",sum(all_rl)/len(all_rl))
print("m: ",sum(all_m)/len(all_m))
# Out:
# On greedy:
# r1:  0.44776543991327095
# r2:  0.2288857440055648
# rl:  0.4016774547092962
# m:  0.39595949524631224

# %%
#beam 3
result3 = predict_step(test_img,24,3)

# %%
predicted3 = []

for i, name in enumerate(test_img):
    predicted3.append(result3[i].split(' '))
    
    
print(len(predicted3))
print(len(actual))
# Out:
# 256
# 256

# %%
print("Beam 3 score:")
print("BLEU-1: %f" % corpus_bleu(actual, predicted3, weights=(1.0, 0, 0, 0)))
print("BLEU-2: %f" % corpus_bleu(actual, predicted3, weights=(0.5, 0.5, 0, 0)))
print("BLEU-3: %f" % corpus_bleu(actual, predicted3, weights=(0.33, 0.33, 0.33, 0)))
print("BLEU-4: %f" % corpus_bleu(actual, predicted3, weights=(0.25, 0.25, 0.25, 0.25)))
# Out:
# Beam 3 score:
# BLEU-1: 0.720528
# BLEU-2: 0.596423
# BLEU-3: 0.492296
# BLEU-4: 0.400462

# %%
all_r1 = []
all_r2 = []
all_rl = []
all_m = []
#s = 0
for i in range(len(actual)):
    #print(s)
    #s+=1
    
    actual_captions = actual[i]
    generated_tokens = predicted3[i]
    #print("predicted: ",generated_tokens)
    rouge = Rouge()
    
    rouge_scores = []
    m_score = []
    reference_tokens = []
    
    for actual_caption in actual_captions:
        reference_tokens = actual_caption
        #print("ref tokens: ",reference_tokens)
        scores = rouge.get_scores(' '.join(generated_tokens), ' '.join(actual_caption))
        rouge_scores.append(scores[0])
        
        meteor_score_value = meteor_score.meteor_score([reference_tokens], generated_tokens)
        m_score.append(meteor_score_value)
    
    #print("rouge:", rouge_scores)
    #print("m:", m_score)
    
    m = sum(m_score)/len(m_score)
    m_score = []
    all_m.append(m)
    
    r1 = []
    r2 = []
    rl = []
    for i, actual_caption in enumerate(actual_captions):
        #print(f"Actual Caption {i+1}: {actual_caption}")
        #print("ROUGE scores:", rouge_scores[i])
        r1.append(rouge_scores[i]['rouge-1']['f'])
        r2.append(rouge_scores[i]['rouge-2']['f'])
        rl.append(rouge_scores[i]['rouge-l']['f'])
        
    all_r1.append(sum(r1)/4)
    all_r2.append(sum(r2)/4)
    all_rl.append(sum(rl)/4)

print("On greedy:")
print("r1: ",sum(all_r1)/len(all_r1))
print("r2: ",sum(all_r2)/len(all_r2))
print("rl: ",sum(all_rl)/len(all_rl))
print("m: ",sum(all_m)/len(all_m))
# Out:
# On greedy:
# r1:  0.44873749794374196
# r2:  0.22590587618067826
# rl:  0.40041263250987397
# m:  0.3927816382740277

# %%
#beam 1
result1 = predict_step(test_img,24,1)

# %%
predicted1 = []

for i, name in enumerate(test_img):
    predicted1.append(result1[i].split(' '))
    
    
print(len(predicted1))
print(len(actual))
# Out:
# 256
# 256

# %%
print("Beam 1 score:")
print("BLEU-1: %f" % corpus_bleu(actual, predicted1, weights=(1.0, 0, 0, 0)))
print("BLEU-2: %f" % corpus_bleu(actual, predicted1, weights=(0.5, 0.5, 0, 0)))
print("BLEU-3: %f" % corpus_bleu(actual, predicted1, weights=(0.33, 0.33, 0.33, 0)))
print("BLEU-4: %f" % corpus_bleu(actual, predicted1, weights=(0.25, 0.25, 0.25, 0.25)))
# Out:
# Beam 1 score:
# BLEU-1: 0.715110
# BLEU-2: 0.577044
# BLEU-3: 0.466591
# BLEU-4: 0.373477

# %%
all_r1 = []
all_r2 = []
all_rl = []
all_m = []
#s = 0
for i in range(len(actual)):
    #print(s)
    #s+=1
    
    actual_captions = actual[i]
    generated_tokens = predicted1[i]
    #print("predicted: ",generated_tokens)
    rouge = Rouge()
    
    rouge_scores = []
    m_score = []
    reference_tokens = []
    
    for actual_caption in actual_captions:
        reference_tokens = actual_caption
        #print("ref tokens: ",reference_tokens)
        scores = rouge.get_scores(' '.join(generated_tokens), ' '.join(actual_caption))
        rouge_scores.append(scores[0])
        
        meteor_score_value = meteor_score.meteor_score([reference_tokens], generated_tokens)
        m_score.append(meteor_score_value)
    
    #print("rouge:", rouge_scores)
    #print("m:", m_score)
    
    m = sum(m_score)/len(m_score)
    m_score = []
    all_m.append(m)
    
    r1 = []
    r2 = []
    rl = []
    for i, actual_caption in enumerate(actual_captions):
        #print(f"Actual Caption {i+1}: {actual_caption}")
        #print("ROUGE scores:", rouge_scores[i])
        r1.append(rouge_scores[i]['rouge-1']['f'])
        r2.append(rouge_scores[i]['rouge-2']['f'])
        rl.append(rouge_scores[i]['rouge-l']['f'])
        
    all_r1.append(sum(r1)/4)
    all_r2.append(sum(r2)/4)
    all_rl.append(sum(rl)/4)

print("On greedy:")
print("r1: ",sum(all_r1)/len(all_r1))
print("r2: ",sum(all_r2)/len(all_r2))
print("rl: ",sum(all_rl)/len(all_rl))
print("m: ",sum(all_m)/len(all_m))
# Out:
# On greedy:
# r1:  0.4327704190950966
# r2:  0.2025218452731147
# rl:  0.3838776638292628
# m:  0.3593393025298319

# %%
file_name = "greedy.txt"  # Change this to your desired file name
file_path = "./exp6/" + file_name  # Change the path if necessary

# Open the file in write mode
with open(file_path, 'w') as file:
    # Iterate over each element in the array
    for element in predicted1:
        # Write the element to a new line in the file
        file.write(' '.join(element) + '\n')

# Print a message indicating the file creation
print(f"The file '{file_name}' has been created and populated with the array elements.")
# Out:
# The file 'greedy.txt' has been created and populated with the array elements.

# %%
file_name = "beam3.txt"  # Change this to your desired file name
file_path = "./exp6/" + file_name  # Change the path if necessary

# Open the file in write mode
with open(file_path, 'w') as file:
    # Iterate over each element in the array
    for element in predicted3:
        # Write the element to a new line in the file
        file.write(' '.join(element) + '\n')

# Print a message indicating the file creation
print(f"The file '{file_name}' has been created and populated with the array elements.")
# Out:
# The file 'beam3.txt' has been created and populated with the array elements.

# %%
file_name = "beam5.txt"  # Change this to your desired file name
file_path = "./exp6/" + file_name  # Change the path if necessary

# Open the file in write mode
with open(file_path, 'w') as file:
    # Iterate over each element in the array
    for element in predicted5:
        # Write the element to a new line in the file
        file.write(' '.join(element) + '\n')

# Print a message indicating the file creation
print(f"The file '{file_name}' has been created and populated with the array elements.")
# Out:
# The file 'beam5.txt' has been created and populated with the array elements.

# %%
file_name = "act1.txt"  # Change this to your desired file name
file_path = "./exp6/" + file_name  # Change the path if necessary

# Open the file in write mode
with open(file_path, 'w') as file:
    # Iterate over each element in the array
    for element in actual:
        el = element[0]
        # Write the element to a new line in the file
        file.write(' '.join(el) + '\n')

# Print a message indicating the file creation
print(f"The file '{file_name}' has been created and populated with the array elements.")
# Out:
# The file 'act1.txt' has been created and populated with the array elements.

# %%
file_name = "act2.txt"  # Change this to your desired file name
file_path = "./exp6/" + file_name  # Change the path if necessary

# Open the file in write mode
with open(file_path, 'w') as file:
    # Iterate over each element in the array
    for element in actual:
        el = element[1]
        # Write the element to a new line in the file
        file.write(' '.join(el) + '\n')

# Print a message indicating the file creation
print(f"The file '{file_name}' has been created and populated with the array elements.")
# Out:
# The file 'act2.txt' has been created and populated with the array elements.

# %%
file_name = "act3.txt"  # Change this to your desired file name
file_path = "./exp6/" + file_name  # Change the path if necessary

# Open the file in write mode
with open(file_path, 'w') as file:
    # Iterate over each element in the array
    for element in actual:
        el = element[2]
        # Write the element to a new line in the file
        file.write(' '.join(el) + '\n')

# Print a message indicating the file creation
print(f"The file '{file_name}' has been created and populated with the array elements.")
# Out:
# The file 'act3.txt' has been created and populated with the array elements.

# %%
file_name = "act4.txt"  # Change this to your desired file name
file_path = "./exp6/" + file_name  # Change the path if necessary

# Open the file in write mode
with open(file_path, 'w') as file:
    # Iterate over each element in the array
    for element in actual:
        el = element[3]
        # Write the element to a new line in the file
        file.write(' '.join(el) + '\n')

# Print a message indicating the file creation
print(f"The file '{file_name}' has been created and populated with the array elements.")
# Out:
# The file 'act4.txt' has been created and populated with the array elements.
